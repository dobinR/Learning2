# %%
import pandas as pd
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import numpy as np
filename = 'C://train_r//data//data0-1.csv'

data = pd.read_csv(filename)
data
# Out:
#         질병 외부 외형 여윔 외부 외형 기형 외부 체표 출혈, 괴사 외부 체표 궤양 외부 체표 흑화 외부 체표 림프 종양  \
# 0    연쇄구균병      NaN      NaN            Y      NaN      NaN         NaN
# 1     기타질병      NaN      NaN          NaN      NaN        Y         NaN
# 2    연쇄구균병      NaN      NaN          NaN      NaN      NaN           Y
# 3     기타질병      NaN      NaN          NaN      NaN      NaN         NaN
# 4     기타질병        Y      NaN          NaN        Y      NaN         NaN
# ..     ...      ...      ...          ...      ...      ...         ...
# 767   기타질병      NaN      NaN          NaN      NaN      NaN         NaN
# 768  스쿠티카병      NaN      NaN          NaN      NaN        Y         NaN
# 769   기타질병      NaN      NaN          NaN      NaN      NaN         NaN
# 770  스쿠티카병      NaN      NaN          NaN      NaN      NaN         NaN
# 771  스쿠티카병      NaN      NaN          NaN      NaN      NaN         NaN
#
#     외부 체표 색소포 \n괴사 외부 안구 혼탁 외부 안구 돌출  ... 내부 장 백색 덩이 내부 장 염증, \n출혈 내부 생식소 괴사  \
# ...

# %%
# data = data.fillna(0)
# data = data.replace('Y', 1)
# data
data.count()
# Out:
# 질병                    772
# 외부 외형 여윔               52
# 외부 외형 기형                4
# 외부 체표 출혈, 괴사            6
# 외부 체표 궤양               17
# 외부 체표 흑화               21
# 외부 체표 림프 종양             5
# 외부 체표 색소포 \n괴사          1
# 외부 안구 혼탁               16
# 외부 안구 돌출                1
# 외부 안구 충혈                6
# 외부 안구 소실                6
# 외부 안구 궤양                6
# 외부 두부 궤양                2
# 외부 두부 출혈성\n염증           1
# 외부 아가미 뚜껑 괴사\n(궤양)      3
# 외부 아가미 뚜껑 내측 출혈        10
# 외부 주둥이 출혈               8
# 외부 주둥이 궤양              24
# 외부 복부 팽만                7
# 외부 복부 함몰                0
# 외부 지느러미 부식             32
# 외부 지느러미 출혈             30
# 외부 지느러미 기저 괴사          15
# 외부 항문 탈장                4
# 외부 항문 출혈                1
# 외부 항문 확장                1
# 내부 복강(복수) 젤라틴           4
# 내부 복강(복수) 투명           15
# 내부 복강(복수) 불투명          10
# 내부 복강(복수) 출혈            5
# 내부 아가미 빈혈             279
# 내부 아가미 출혈               0
# 내부 아가미 괴사              89
# 내부 아가미 부식               1
# ...

# %%
data_1 = data.groupby(by=['질병'], as_index=False).count()
data_2 = data.groupby(by=['질병'], as_index=False).count()
data_1
# Out:
#       질병  외부 외형 여윔  외부 외형 기형  외부 체표 출혈, 괴사  외부 체표 궤양  외부 체표 흑화  외부 체표 림프 종양  \
# 0   VHSV         0         0             0         0         0            0
# 1   기타질병        14         1             1         4         2            3
# 2  비브리오병        14         0             0         8         3            1
# 3  스쿠티카병         5         1             3         0         1            0
# 4  에드워드병         1         0             1         0         0            0
# 5  연쇄구균병         5         2             1         1        11            1
# 6     정상        12         0             0         3         4            0
# 7  활주세균병         1         0             0         1         0            0
#
#    외부 체표 색소포 \n괴사  외부 안구 혼탁  외부 안구 돌출  ...  내부 장 백색 덩이  내부 장 염증, \n출혈  \
# 0               0         0         0  ...           0              0
# 1               0         4         0  ...           1              3
# 2               1         5         0  ...           0              2
# ...

# %%
data_1
# Out:
#       질병  외부 외형 여윔  외부 외형 기형  외부 체표 출혈, 괴사  외부 체표 궤양  외부 체표 흑화  외부 체표 림프 종양  \
# 0   VHSV         0         0             0         0         0            0
# 1   기타질병        14         1             1         4         2            3
# 2  비브리오병        14         0             0         8         3            1
# 3  스쿠티카병         5         1             3         0         1            0
# 4  에드워드병         1         0             1         0         0            0
# 5  연쇄구균병         5         2             1         1        11            1
# 6     정상        12         0             0         3         4            0
# 7  활주세균병         1         0             0         1         0            0
#
#    외부 체표 색소포 \n괴사  외부 안구 혼탁  외부 안구 돌출  ...  내부 장 백색 덩이  내부 장 염증, \n출혈  \
# 0               0         0         0  ...           0              0
# 1               0         4         0  ...           1              3
# 2               1         5         0  ...           0              2
# ...

# %%
data_1['외부 외형 여윔'].value_counts()
# Out:
# 14    2
# 5     2
# 1     2
# 0     1
# 12    1
# Name: 외부 외형 여윔, dtype: int64

# %%
data_1.loc[:]
# Out:
#       질병  외부 외형 여윔  외부 외형 기형  외부 체표 출혈, 괴사  외부 체표 궤양  외부 체표 흑화  외부 체표 림프 종양  \
# 0   VHSV         0         0             0         0         0            0
# 1   기타질병        14         1             1         4         2            3
# 2  비브리오병        14         0             0         8         3            1
# 3  스쿠티카병         5         1             3         0         1            0
# 4  에드워드병         1         0             1         0         0            0
# 5  연쇄구균병         5         2             1         1        11            1
# 6     정상        12         0             0         3         4            0
# 7  활주세균병         1         0             0         1         0            0
#
#    외부 체표 색소포 \n괴사  외부 안구 혼탁  외부 안구 돌출  ...  내부 장 백색 덩이  내부 장 염증, \n출혈  \
# 0               0         0         0  ...           0              0
# 1               0         4         0  ...           1              3
# 2               1         5         0  ...           0              2
# ...

# %%
data_1
# Out:
#       질병  외부 외형 여윔  외부 외형 기형  외부 체표 출혈, 괴사  외부 체표 궤양  외부 체표 흑화  외부 체표 림프 종양  \
# 0   VHSV         0         0             0         0         0            0
# 1   기타질병        14         1             1         4         2            3
# 2  비브리오병        14         0             0         8         3            1
# 3  스쿠티카병         5         1             3         0         1            0
# 4  에드워드병         1         0             1         0         0            0
# 5  연쇄구균병         5         2             1         1        11            1
# 6     정상        12         0             0         3         4            0
# 7  활주세균병         1         0             0         1         0            0
#
#    외부 체표 색소포 \n괴사  외부 안구 혼탁  외부 안구 돌출  ...  내부 장 백색 덩이  내부 장 염증, \n출혈  \
# 0               0         0         0  ...           0              0
# 1               0         4         0  ...           1              3
# 2               1         5         0  ...           0              2
# ...

# %%
for i in range(1, 57):
    for j in range(8):
        if data_1.iloc[j,i] == 0:
            pass
        else:
            data_2.iloc[j,i] = round((data_1.iloc[j,i] / data_1.iloc[:,i].sum()) * 100, 2)

# %%
data.count()
# Out:
# 질병                    772
# 외부 외형 여윔               52
# 외부 외형 기형                4
# 외부 체표 출혈, 괴사            6
# 외부 체표 궤양               17
# 외부 체표 흑화               21
# 외부 체표 림프 종양             5
# 외부 체표 색소포 \n괴사          1
# 외부 안구 혼탁               16
# 외부 안구 돌출                1
# 외부 안구 충혈                6
# 외부 안구 소실                6
# 외부 안구 궤양                6
# 외부 두부 궤양                2
# 외부 두부 출혈성\n염증           1
# 외부 아가미 뚜껑 괴사\n(궤양)      3
# 외부 아가미 뚜껑 내측 출혈        10
# 외부 주둥이 출혈               8
# 외부 주둥이 궤양              24
# 외부 복부 팽만                7
# 외부 복부 함몰                0
# 외부 지느러미 부식             32
# 외부 지느러미 출혈             30
# 외부 지느러미 기저 괴사          15
# 외부 항문 탈장                4
# 외부 항문 출혈                1
# 외부 항문 확장                1
# 내부 복강(복수) 젤라틴           4
# 내부 복강(복수) 투명           15
# 내부 복강(복수) 불투명          10
# 내부 복강(복수) 출혈            5
# 내부 아가미 빈혈             279
# 내부 아가미 출혈               0
# 내부 아가미 괴사              89
# 내부 아가미 부식               1
# ...

# %%
data_2
# Out:
#       질병  외부 외형 여윔  외부 외형 기형  외부 체표 출혈, 괴사  외부 체표 궤양  외부 체표 흑화  외부 체표 림프 종양  \
# 0   VHSV      0.00         0          0.00      0.00      0.00            0
# 1   기타질병     26.92        25         16.67     23.53      9.52           60
# 2  비브리오병     26.92         0          0.00     47.06     14.29           20
# 3  스쿠티카병      9.62        25         50.00      0.00      4.76            0
# 4  에드워드병      1.92         0         16.67      0.00      0.00            0
# 5  연쇄구균병      9.62        50         16.67      5.88     52.38           20
# 6     정상     23.08         0          0.00     17.65     19.05            0
# 7  활주세균병      1.92         0          0.00      5.88      0.00            0
#
#    외부 체표 색소포 \n괴사  외부 안구 혼탁  외부 안구 돌출  ...  내부 장 백색 덩이  내부 장 염증, \n출혈  \
# 0               0      0.00         0  ...           0           0.00
# 1               0     25.00         0  ...         100          42.86
# 2             100     31.25         0  ...           0          28.57
# ...

# %%
df=data_2.transpose()
df
# Out:
#                         0      1      2      3      4      5      6      7
# 질병                   VHSV   기타질병  비브리오병  스쿠티카병  에드워드병  연쇄구균병     정상  활주세균병
# 외부 외형 여윔              0.0  26.92  26.92   9.62   1.92   9.62  23.08   1.92
# 외부 외형 기형                0     25      0     25      0     50      0      0
# 외부 체표 출혈, 괴사          0.0  16.67    0.0   50.0  16.67  16.67    0.0    0.0
# 외부 체표 궤양              0.0  23.53  47.06    0.0    0.0   5.88  17.65   5.88
# 외부 체표 흑화              0.0   9.52  14.29   4.76    0.0  52.38  19.05    0.0
# 외부 체표 림프 종양             0     60     20      0      0     20      0      0
# 외부 체표 색소포 \n괴사          0      0    100      0      0      0      0      0
# 외부 안구 혼탁              0.0   25.0  31.25    0.0   6.25  18.75  18.75    0.0
# 외부 안구 돌출                0      0      0      0      0    100      0      0
# 외부 안구 충혈              0.0  66.67    0.0    0.0    0.0  16.67  16.67    0.0
# ...

# %%
df["총 데이터 수"] = data.count()
df["데이터당 증상 비율"] = data.count()
# Out:
#                         0      1      2      3      4      5      6      7  \
# 질병                   VHSV   기타질병  비브리오병  스쿠티카병  에드워드병  연쇄구균병     정상  활주세균병
# 외부 외형 여윔              0.0  26.92  26.92   9.62   1.92   9.62  23.08   1.92
# 외부 외형 기형                0     25      0     25      0     50      0      0
# 외부 체표 출혈, 괴사          0.0  16.67    0.0   50.0  16.67  16.67    0.0    0.0
# 외부 체표 궤양              0.0  23.53  47.06    0.0    0.0   5.88  17.65   5.88
# 외부 체표 흑화              0.0   9.52  14.29   4.76    0.0  52.38  19.05    0.0
# 외부 체표 림프 종양             0     60     20      0      0     20      0      0
# 외부 체표 색소포 \n괴사          0      0    100      0      0      0      0      0
# 외부 안구 혼탁              0.0   25.0  31.25    0.0   6.25  18.75  18.75    0.0
# 외부 안구 돌출                0      0      0      0      0    100      0      0
# 외부 안구 충혈              0.0  66.67    0.0    0.0    0.0  16.67  16.67    0.0
# ...

# %%
data_3 = df

for i in range(1, 57):
    if df.iloc[i,8] == 0:
        pass
    else:
        df.iloc[i,9] = round(data_3.iloc[i,8]/data_3.iloc[0,8] * 100, 2)
df
# Out:
#                         0      1      2      3      4      5      6      7  \
# 질병                   VHSV   기타질병  비브리오병  스쿠티카병  에드워드병  연쇄구균병     정상  활주세균병
# 외부 외형 여윔              0.0  26.92  26.92   9.62   1.92   9.62  23.08   1.92
# 외부 외형 기형                0     25      0     25      0     50      0      0
# 외부 체표 출혈, 괴사          0.0  16.67    0.0   50.0  16.67  16.67    0.0    0.0
# 외부 체표 궤양              0.0  23.53  47.06    0.0    0.0   5.88  17.65   5.88
# 외부 체표 흑화              0.0   9.52  14.29   4.76    0.0  52.38  19.05    0.0
# 외부 체표 림프 종양             0     60     20      0      0     20      0      0
# 외부 체표 색소포 \n괴사          0      0    100      0      0      0      0      0
# 외부 안구 혼탁              0.0   25.0  31.25    0.0   6.25  18.75  18.75    0.0
# 외부 안구 돌출                0      0      0      0      0    100      0      0
# 외부 안구 충혈              0.0  66.67    0.0    0.0    0.0  16.67  16.67    0.0
# ...
